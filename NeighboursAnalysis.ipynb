# %%
#Load the data 
import pandas as pd
scores_data_one = pd.read_csv('scores_main.csv')
scores_data_one.head()
# Out:
#    Unnamed: 0 Algorithm                      Dataset  \
# 0           0  Original  setapProcessT1_updated1.csv
# 1           1  Original  setapProcessT1_updated1.csv
# 2           2  Original  setapProcessT1_updated1.csv
# 3           3  Original  setapProcessT1_updated1.csv
# 4           4  Original  setapProcessT1_updated1.csv
#
#                        Model  Fold Number  Accuracy        F1  Geometric Mean  \
# 0  Support Vector Classifier            1  0.692308  0.818182         0.00000
# 1  Support Vector Classifier            2  0.615385  0.705882         0.57735
# 2  Support Vector Classifier            3  0.615385  0.761905         0.00000
# 3  Support Vector Classifier            4  0.692308  0.818182         0.00000
# 4  Support Vector Classifier            5  0.500000  0.666667         0.00000
#
#         AUC  Precision    Recall
# 0  0.694444   0.692308  1.000000
# 1  0.527778   0.750000  0.666667
# 2  0.638889   0.666667  0.888889
# 3  0.361111   0.692308  1.000000
# ...

# %%
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_one = scores_data_one.drop(column_name_to_remove, axis=1)
scores_data_one.head()
scores_data_one.tail()
# Out:
#              Algorithm       Dataset                Model  Fold Number  \
# 2995  Variable ReliefF  leukemia.csv  K Nearest Neighbour            1
# 2996  Variable ReliefF  leukemia.csv  K Nearest Neighbour            2
# 2997  Variable ReliefF  leukemia.csv  K Nearest Neighbour            3
# 2998  Variable ReliefF  leukemia.csv  K Nearest Neighbour            4
# 2999  Variable ReliefF  leukemia.csv  K Nearest Neighbour            5
#
#       Accuracy        F1  Geometric Mean       AUC  Precision  Recall
# 2995  0.933333  0.952381        0.894427  1.000000   0.909091     1.0
# 2996  0.933333  0.952381        0.894427  1.000000   0.909091     1.0
# 2997  1.000000  1.000000        1.000000  1.000000   1.000000     1.0
# 2998  0.714286  0.818182        0.447214  0.866667   0.692308     1.0
# 2999  0.857143  0.900000        0.774597  0.955556   0.818182     1.0

# %%
#Load the data 
import pandas as pd
scores_data_two = pd.read_csv('scores_main_reliefTwo.csv')
# scores_data_two = pd.read_csv('scores_reliefFThree.csv')

scores_data_two.head()
# Out:
#    Unnamed: 0   Algorithm                      Dataset  \
# 0           0  ReliefFTwo  setapProcessT1_updated1.csv
# 1           1  ReliefFTwo  setapProcessT1_updated1.csv
# 2           2  ReliefFTwo  setapProcessT1_updated1.csv
# 3           3  ReliefFTwo  setapProcessT1_updated1.csv
# 4           4  ReliefFTwo  setapProcessT1_updated1.csv
#
#                        Model  Fold Number  Accuracy        F1  Geometric Mean  \
# 0  Support Vector Classifier            1  0.692308  0.818182        0.000000
# 1  Support Vector Classifier            2  0.538462  0.666667        0.408248
# 2  Support Vector Classifier            3  0.615385  0.761905        0.000000
# 3  Support Vector Classifier            4  0.692308  0.818182        0.000000
# 4  Support Vector Classifier            5  0.416667  0.588235        0.000000
#
#         AUC  Precision    Recall
# 0  0.277778   0.692308  1.000000
# 1  0.555556   0.666667  0.666667
# 2  0.666667   0.666667  0.888889
# ...

# %%
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_two = scores_data_two.drop(column_name_to_remove, axis=1)
scores_data_two.head()
scores_data_two.tail()
# Out:
#       Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  0.866667
# 596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.642857
# 599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.857143
#
#            F1  Geometric Mean       AUC  Precision  Recall
# 595  0.909091        0.774597  0.940000   0.833333     1.0
# 596  0.952381        0.894427  1.000000   0.909091     1.0
# 597  1.000000        1.000000  1.000000   1.000000     1.0
# 598  0.782609        0.000000  0.600000   0.642857     1.0
# 599  0.900000        0.774597  0.966667   0.818182     1.0

# %%
scores_data = pd.concat([scores_data_one, scores_data_two], ignore_index=True)

# %%
#Load the data 
import pandas as pd
scores_data_3 = pd.read_csv('scores_main_neighbors_3.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_3 = scores_data_3.drop(column_name_to_remove, axis=1)
scores_data_3.head()
scores_data_3.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.785714
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.857143
#
#             F1  Geometric Mean  AUC  Precision  Recall
# 3595  1.000000        1.000000  1.0   1.000000     1.0
# 3596  0.952381        0.894427  1.0   0.909091     1.0
# 3597  1.000000        1.000000  1.0   1.000000     1.0
# 3598  0.857143        0.632456  0.9   0.750000     1.0
# 3599  0.900000        0.774597  1.0   0.818182     1.0

# %%
#Load the data 
import pandas as pd
scores_data_7 = pd.read_csv('scores_main_neighbors_7.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_7 = scores_data_7.drop(column_name_to_remove, axis=1)
scores_data_7.head()
scores_data_7.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.857143
#
#             F1  Geometric Mean       AUC  Precision  Recall
# 3595  1.000000        1.000000  1.000000   1.000000     1.0
# 3596  0.952381        0.894427  1.000000   0.909091     1.0
# 3597  1.000000        1.000000  1.000000   1.000000     1.0
# 3598  0.818182        0.447214  0.833333   0.692308     1.0
# 3599  0.900000        0.774597  0.955556   0.818182     1.0

# %%
#Load the data 
import pandas as pd
scores_data_9 = pd.read_csv('scores_main_neighbors_9.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_9 = scores_data_9.drop(column_name_to_remove, axis=1)
scores_data_9.head()
scores_data_9.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.785714
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision    Recall
# 3595  1.000000        1.000000  1.000000   1.000000  1.000000
# 3596  0.952381        0.894427  1.000000   0.909091  1.000000
# 3597  0.941176        0.942809  0.988889   1.000000  0.888889
# 3598  0.857143        0.632456  0.855556   0.750000  1.000000
# 3599  0.947368        0.894427  0.955556   0.900000  1.000000

# %%
#Load the data 
import pandas as pd
scores_data_11 = pd.read_csv('scores_main_neighbors_11.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_11 = scores_data_11.drop(column_name_to_remove, axis=1)
scores_data_11.head()
scores_data_11.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  1.000000
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision  Recall
# 3595  1.000000        1.000000  1.000000   1.000000     1.0
# 3596  1.000000        1.000000  1.000000   1.000000     1.0
# 3597  1.000000        1.000000  1.000000   1.000000     1.0
# 3598  0.818182        0.447214  0.933333   0.692308     1.0
# 3599  0.947368        0.894427  0.955556   0.900000     1.0

# %%
meanF1_main = scores_data["F1"].mean()
meanF1_3 = scores_data_3["F1"].mean()
meanF1_7 = scores_data_7["F1"].mean()
meanF1_9 = scores_data_9["F1"].mean()
meanF1_11 = scores_data_11["F1"].mean()

# %%
import matplotlib.pyplot as plt
# Mean F1 scores for various datasets
datasets = [
    "5",
    "3",
    "7 (Main)",
    "9",
    "11",
 
]
mean_f1_scores_datasets = [
    meanF1_main,
    meanF1_3,
    meanF1_7,
    meanF1_9,
    meanF1_11
]

mean_f1_scores_datasets = [
    meanF1_main,
    meanF1_3,
    meanF1_11,
    meanF1_9,
    meanF1_7
]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(datasets, mean_f1_scores_datasets, color='seagreen')
plt.xlabel('Number of Neigbors',fontsize='large')
plt.ylabel('Mean F1 Score',fontsize='large')
plt.title('Mean F1 Scores',fontsize='large')
plt.tight_layout()

plt.show()

# %%
meanF1_main = scores_data["Accuracy"].mean()
meanF1_3 = scores_data_3["Accuracy"].mean()
meanF1_7 = scores_data_7["Accuracy"].mean()
meanF1_9 = scores_data_9["Accuracy"].mean()
meanF1_11 = scores_data_11["Accuracy"].mean()

# %%
# Mean F1 scores for various datasets
datasets = [
    "5",
    "3",
    "7 (Main)",
    "9",
    "11",
 
]
# mean_f1_scores_datasets = [
#     meanF1_main,
#     meanF1_3,
#     meanF1_7,
#     meanF1_9,
#     meanF1_11
# ]
mean_f1_scores_datasets = [
    meanF1_main,
    meanF1_3,
    meanF1_11,
    meanF1_9,
    meanF1_7
]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(datasets, mean_f1_scores_datasets, color='seagreen')
plt.xlabel('Number of Neigbors',fontsize='large')
plt.ylabel('Mean Accuracy',fontsize='large')
plt.title('Mean Accuracy',fontsize='large')
plt.tight_layout()

plt.show()

# %%
metric = "Accuracy"
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour")][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors', '7 neighbors (main)', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
metric = "F1"
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour")][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors', '7 neighbors (main)', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
metric = "Precision"
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour")][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors', '7 neighbors (main)', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Precision Comparison', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
metric = "Recall"
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour")][metric].mean()

mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier")][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier")][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier")][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes")][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier")][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour")][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Recall Comparison', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### Original

# %%
algorithm = "Original"  # Replace with your specific algorithm
metric = "F1"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison (Original)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
algorithm = "Original"  # Replace with your specific algorithm
metric = "Accuracy"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (Original)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### SVMRFE

# %%
algorithm = "SVMRFE"  # Replace with your specific algorithm
metric = "F1"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison (SVMRFE)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
algorithm = "SVMRFE"  # Replace with your specific algorithm
metric = "Accuracy"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (SVMRFE)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### ChiSquare

# %%
algorithm = "ChiSquare"  # Replace with your specific algorithm
metric = "F1"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison (ChiSquare)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
algorithm = "ChiSquare"  # Replace with your specific algorithm
metric = "Accuracy"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (ChiSquare)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### ReliefF

# %%
algorithm = "ReliefF"  # Replace with your specific algorithm
metric = "F1"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison (ReliefF)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
algorithm = "ReliefF"  # Replace with your specific algorithm
metric = "Accuracy"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (ReliefF)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### RiceVD

# %%
algorithm = "Variable ReliefF"  # Replace with your specific algorithm
metric = "F1"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison (RiceVD-Sujit)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
algorithm = "Variable ReliefF"  # Replace with your specific algorithm
metric = "Accuracy"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors (main)', '7 neighbors', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (RiceVD-Sujit)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### RiceVDTwo

# %%
algorithm = "ReliefFTwo"  # Replace with your specific algorithm
metric = "F1"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_65_svc, mean_accuracy_60_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_65_dt,  mean_accuracy_60_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_75_rf, mean_accuracy_65_rf, mean_accuracy_60_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_75_nb, mean_accuracy_65_nb, mean_accuracy_60_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_65_gb,  mean_accuracy_60_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_65_knn,  mean_accuracy_60_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors', '7 neighbors (main)', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='F1 Comparison (RiceVD)', color=colors, width=0.7,fontsize='large')

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2,fontsize='large')

# Show the plot
plt.show()

# %%
algorithm = "ReliefFTwo"  # Replace with your specific algorithm
metric = "Accuracy"  # Replace MetricName with "Accuracy" or any other metric you're analyzing

# Main dataset
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier") & (scores_data["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour") & (scores_data["Algorithm"] == algorithm)][metric].mean()

# Dataset 55, now represented as scores_data_3
mean_accuracy_55_svc = scores_data_3[(scores_data_3["Model"] == "Support Vector Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_dt = scores_data_3[(scores_data_3["Model"] == "Decision Tree Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_rf = scores_data_3[(scores_data_3["Model"] == "Random Forest Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_nb = scores_data_3[(scores_data_3["Model"] == "Gaussian Naive Bayes") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_gb = scores_data_3[(scores_data_3["Model"] == "Gradient Boosting Classifier") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_55_knn = scores_data_3[(scores_data_3["Model"] == "K Nearest Neighbour") & (scores_data_3["Algorithm"] == algorithm)][metric].mean()

# Dataset 60, now represented as scores_data_7
mean_accuracy_60_svc = scores_data_7[(scores_data_7["Model"] == "Support Vector Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_dt = scores_data_7[(scores_data_7["Model"] == "Decision Tree Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_rf = scores_data_7[(scores_data_7["Model"] == "Random Forest Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_nb = scores_data_7[(scores_data_7["Model"] == "Gaussian Naive Bayes") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_gb = scores_data_7[(scores_data_7["Model"] == "Gradient Boosting Classifier") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_60_knn = scores_data_7[(scores_data_7["Model"] == "K Nearest Neighbour") & (scores_data_7["Algorithm"] == algorithm)][metric].mean()

# Dataset 65, now represented as scores_data_9
mean_accuracy_65_svc = scores_data_9[(scores_data_9["Model"] == "Support Vector Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_dt = scores_data_9[(scores_data_9["Model"] == "Decision Tree Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_rf = scores_data_9[(scores_data_9["Model"] == "Random Forest Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_nb = scores_data_9[(scores_data_9["Model"] == "Gaussian Naive Bayes") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_gb = scores_data_9[(scores_data_9["Model"] == "Gradient Boosting Classifier") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_65_knn = scores_data_9[(scores_data_9["Model"] == "K Nearest Neighbour") & (scores_data_9["Algorithm"] == algorithm)][metric].mean()

# Dataset 75, now represented as scores_data_11
mean_accuracy_75_svc = scores_data_11[(scores_data_11["Model"] == "Support Vector Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_dt = scores_data_11[(scores_data_11["Model"] == "Decision Tree Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_rf = scores_data_11[(scores_data_11["Model"] == "Random Forest Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_nb = scores_data_11[(scores_data_11["Model"] == "Gaussian Naive Bayes") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_gb = scores_data_11[(scores_data_11["Model"] == "Gradient Boosting Classifier") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()
mean_accuracy_75_knn = scores_data_11[(scores_data_11["Model"] == "K Nearest Neighbour") & (scores_data_11["Algorithm"] == algorithm)][metric].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_main_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_75_svc],
    'Decision Tree': [mean_accuracy_55_dt,mean_accuracy_main_dt, mean_accuracy_60_dt, mean_accuracy_65_dt,  mean_accuracy_75_dt],
    'Random Forest': [mean_accuracy_55_rf,mean_accuracy_main_rf,  mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_75_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_main_nb,  mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_75_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_main_gb, mean_accuracy_60_gb, mean_accuracy_65_gb,  mean_accuracy_75_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_main_knn, mean_accuracy_60_knn, mean_accuracy_65_knn,  mean_accuracy_75_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['3 neighbors', '5 neighbors', '7 neighbors (main)', '9 neighbors', '11 neighbors'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (RiceVD)', color=colors, width=0.7,fontsize='large')

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2,fontsize='large')

# Show the plot
plt.show()
