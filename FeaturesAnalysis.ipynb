# %%
#Load the data 
import pandas as pd
scores_data_one = pd.read_csv('scores_main.csv')
scores_data_one.head()
# Out:
#    Unnamed: 0 Algorithm                      Dataset  \
# 0           0  Original  setapProcessT1_updated1.csv
# 1           1  Original  setapProcessT1_updated1.csv
# 2           2  Original  setapProcessT1_updated1.csv
# 3           3  Original  setapProcessT1_updated1.csv
# 4           4  Original  setapProcessT1_updated1.csv
#
#                        Model  Fold Number  Accuracy        F1  Geometric Mean  \
# 0  Support Vector Classifier            1  0.692308  0.818182         0.00000
# 1  Support Vector Classifier            2  0.615385  0.705882         0.57735
# 2  Support Vector Classifier            3  0.615385  0.761905         0.00000
# 3  Support Vector Classifier            4  0.692308  0.818182         0.00000
# 4  Support Vector Classifier            5  0.500000  0.666667         0.00000
#
#         AUC  Precision    Recall
# 0  0.694444   0.692308  1.000000
# 1  0.527778   0.750000  0.666667
# 2  0.638889   0.666667  0.888889
# 3  0.361111   0.692308  1.000000
# ...

# %%
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_one = scores_data_one.drop(column_name_to_remove, axis=1)
scores_data_one.head()
scores_data_one.tail()
# Out:
#              Algorithm       Dataset                Model  Fold Number  \
# 2995  Variable ReliefF  leukemia.csv  K Nearest Neighbour            1
# 2996  Variable ReliefF  leukemia.csv  K Nearest Neighbour            2
# 2997  Variable ReliefF  leukemia.csv  K Nearest Neighbour            3
# 2998  Variable ReliefF  leukemia.csv  K Nearest Neighbour            4
# 2999  Variable ReliefF  leukemia.csv  K Nearest Neighbour            5
#
#       Accuracy        F1  Geometric Mean       AUC  Precision  Recall
# 2995  0.933333  0.952381        0.894427  1.000000   0.909091     1.0
# 2996  0.933333  0.952381        0.894427  1.000000   0.909091     1.0
# 2997  1.000000  1.000000        1.000000  1.000000   1.000000     1.0
# 2998  0.714286  0.818182        0.447214  0.866667   0.692308     1.0
# 2999  0.857143  0.900000        0.774597  0.955556   0.818182     1.0

# %%
#Load the data 
import pandas as pd
scores_data_two = pd.read_csv('scores_main_reliefTwo.csv')
# scores_data_two = pd.read_csv('scores_reliefFThree.csv')

scores_data_two.head()
# Out:
#    Unnamed: 0   Algorithm                      Dataset  \
# 0           0  ReliefFTwo  setapProcessT1_updated1.csv
# 1           1  ReliefFTwo  setapProcessT1_updated1.csv
# 2           2  ReliefFTwo  setapProcessT1_updated1.csv
# 3           3  ReliefFTwo  setapProcessT1_updated1.csv
# 4           4  ReliefFTwo  setapProcessT1_updated1.csv
#
#                        Model  Fold Number  Accuracy        F1  Geometric Mean  \
# 0  Support Vector Classifier            1  0.692308  0.818182        0.000000
# 1  Support Vector Classifier            2  0.538462  0.666667        0.408248
# 2  Support Vector Classifier            3  0.615385  0.761905        0.000000
# 3  Support Vector Classifier            4  0.692308  0.818182        0.000000
# 4  Support Vector Classifier            5  0.416667  0.588235        0.000000
#
#         AUC  Precision    Recall
# 0  0.277778   0.692308  1.000000
# 1  0.555556   0.666667  0.666667
# 2  0.666667   0.666667  0.888889
# ...

# %%
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_two = scores_data_two.drop(column_name_to_remove, axis=1)
scores_data_two.head()
scores_data_two.tail()
# Out:
#       Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  0.866667
# 596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.642857
# 599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.857143
#
#            F1  Geometric Mean       AUC  Precision  Recall
# 595  0.909091        0.774597  0.940000   0.833333     1.0
# 596  0.952381        0.894427  1.000000   0.909091     1.0
# 597  1.000000        1.000000  1.000000   1.000000     1.0
# 598  0.782609        0.000000  0.600000   0.642857     1.0
# 599  0.900000        0.774597  0.966667   0.818182     1.0

# %%
#Merging the two dataframes 
# Merge the data frames
scores_data = pd.concat([scores_data_one, scores_data_two], ignore_index=True)

# %%
scores_data.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  0.866667
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.642857
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.857143
#
#             F1  Geometric Mean       AUC  Precision  Recall
# 3595  0.909091        0.774597  0.940000   0.833333     1.0
# 3596  0.952381        0.894427  1.000000   0.909091     1.0
# 3597  1.000000        1.000000  1.000000   1.000000     1.0
# 3598  0.782609        0.000000  0.600000   0.642857     1.0
# 3599  0.900000        0.774597  0.966667   0.818182     1.0

# %%
#Load the data 
import pandas as pd
scores_data_55 = pd.read_csv('scores_main_feature_55.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_55 = scores_data_55.drop(column_name_to_remove, axis=1)
scores_data_55.head()
scores_data_55.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  1.000000
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision  Recall
# 3595  1.000000        1.000000  1.000000   1.000000     1.0
# 3596  1.000000        1.000000  1.000000   1.000000     1.0
# 3597  1.000000        1.000000  1.000000   1.000000     1.0
# 3598  0.818182        0.447214  0.888889   0.692308     1.0
# 3599  0.947368        0.894427  1.000000   0.900000     1.0

# %%
#Load the data 
import pandas as pd
scores_data_60 = pd.read_csv('scores_main_feature_60.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_60 = scores_data_60.drop(column_name_to_remove, axis=1)
scores_data_60.head()
scores_data_60.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.785714
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision    Recall
# 3595  1.000000        1.000000  1.000000   1.000000  1.000000
# 3596  0.952381        0.894427  1.000000   0.909091  1.000000
# 3597  0.941176        0.942809  0.988889   1.000000  0.888889
# 3598  0.857143        0.632456  0.877778   0.750000  1.000000
# 3599  0.947368        0.894427  0.988889   0.900000  1.000000

# %%
#Load the data 
import pandas as pd
scores_data_65 = pd.read_csv('scores_main_feature_65.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_65 = scores_data_65.drop(column_name_to_remove, axis=1)
scores_data_65.head()
scores_data_65.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision  Recall
# 3595  1.000000        1.000000  1.000000   1.000000     1.0
# 3596  0.952381        0.894427  1.000000   0.909091     1.0
# 3597  1.000000        1.000000  1.000000   1.000000     1.0
# 3598  0.818182        0.447214  0.855556   0.692308     1.0
# 3599  0.947368        0.894427  0.966667   0.900000     1.0

# %%
#Load the data 
import pandas as pd
scores_data_75 = pd.read_csv('scores_main_feature_75.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_75 = scores_data_75.drop(column_name_to_remove, axis=1)
scores_data_75.head()
scores_data_75.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision    Recall
# 3595  1.000000        1.000000  1.000000   1.000000  1.000000
# 3596  0.952381        0.894427  1.000000   0.909091  1.000000
# 3597  0.941176        0.942809  0.988889   1.000000  0.888889
# 3598  0.818182        0.447214  0.911111   0.692308  1.000000
# 3599  0.947368        0.894427  0.944444   0.900000  1.000000

# %%
#Load the data 
import pandas as pd
scores_data_80 = pd.read_csv('scores_main_feature_80.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_80 = scores_data_80.drop(column_name_to_remove, axis=1)
scores_data_80.head()
scores_data_80.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision    Recall
# 3595  1.000000        1.000000  1.000000   1.000000  1.000000
# 3596  0.952381        0.894427  1.000000   0.909091  1.000000
# 3597  0.941176        0.942809  0.988889   1.000000  0.888889
# 3598  0.818182        0.447214  0.822222   0.692308  1.000000
# 3599  0.947368        0.894427  0.944444   0.900000  1.000000

# %%
#Load the data 
import pandas as pd
scores_data_85 = pd.read_csv('scores_main_feature_85.csv')
#Dropping the indexed column
column_name_to_remove = 'Unnamed: 0'
scores_data_85 = scores_data_85.drop(column_name_to_remove, axis=1)
scores_data_85.head()
scores_data_85.tail()
# Out:
#        Algorithm       Dataset                Model  Fold Number  Accuracy  \
# 3595  ReliefFTwo  leukemia.csv  K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia.csv  K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia.csv  K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia.csv  K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia.csv  K Nearest Neighbour            5  0.928571
#
#             F1  Geometric Mean       AUC  Precision    Recall
# 3595  1.000000        1.000000  1.000000   1.000000  1.000000
# 3596  0.952381        0.894427  1.000000   0.909091  1.000000
# 3597  0.941176        0.942809  0.988889   1.000000  0.888889
# 3598  0.818182        0.447214  0.766667   0.692308  1.000000
# 3599  0.947368        0.894427  0.944444   0.900000  1.000000

# %%
# Updating the 'Dataset' column values to "T1" where the current value is "setapProcessT1_updated1.csv"
scores_data.loc[scores_data['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data.loc[scores_data['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data.loc[scores_data['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data.loc[scores_data['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data.loc[scores_data['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data.loc[scores_data['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data.loc[scores_data['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data.loc[scores_data['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data.loc[scores_data['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data.loc[scores_data['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data.loc[scores_data['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'


# Displaying the updated DataFrame to confirm the change
scores_data
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  0.866667
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.642857
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.857143
#
# ...

# %%
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data_55.loc[scores_data_55['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data_55.loc[scores_data_55['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data_55.loc[scores_data_55['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data_55.loc[scores_data_55['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data_55.loc[scores_data_55['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data_55.loc[scores_data_55['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data_55.loc[scores_data_55['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data_55.loc[scores_data_55['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data_55.loc[scores_data_55['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data_55.loc[scores_data_55['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'

# Displaying the updated DataFrame to confirm the change
scores_data_55
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  1.000000
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.928571
#
# ...

# %%
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data_65.loc[scores_data_65['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data_65.loc[scores_data_65['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data_65.loc[scores_data_65['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data_65.loc[scores_data_65['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data_65.loc[scores_data_65['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data_65.loc[scores_data_65['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data_65.loc[scores_data_65['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data_65.loc[scores_data_65['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data_65.loc[scores_data_65['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data_65.loc[scores_data_65['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'

# Displaying the updated DataFrame to confirm the change
scores_data_65
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  1.000000
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.928571
#
# ...

# %%
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data_60.loc[scores_data_60['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data_60.loc[scores_data_60['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data_60.loc[scores_data_60['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data_60.loc[scores_data_60['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data_60.loc[scores_data_60['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data_60.loc[scores_data_60['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data_60.loc[scores_data_60['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data_60.loc[scores_data_60['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data_60.loc[scores_data_60['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data_60.loc[scores_data_60['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'

# Displaying the updated DataFrame to confirm the change
scores_data_60
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.785714
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.928571
#
# ...

# %%
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data_75.loc[scores_data_75['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data_75.loc[scores_data_75['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data_75.loc[scores_data_75['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data_75.loc[scores_data_75['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data_75.loc[scores_data_75['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data_75.loc[scores_data_75['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data_75.loc[scores_data_75['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data_75.loc[scores_data_75['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data_75.loc[scores_data_75['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data_75.loc[scores_data_75['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'

# Displaying the updated DataFrame to confirm the change
scores_data_75
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.928571
#
# ...

# %%
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data_80.loc[scores_data_80['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data_80.loc[scores_data_80['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data_80.loc[scores_data_80['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data_80.loc[scores_data_80['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data_80.loc[scores_data_80['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data_80.loc[scores_data_80['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data_80.loc[scores_data_80['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data_80.loc[scores_data_80['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data_80.loc[scores_data_80['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data_80.loc[scores_data_80['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'

# Displaying the updated DataFrame to confirm the change
scores_data_80
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.928571
#
# ...

# %%
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT1_updated1.csv', 'Dataset'] = 'T1'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT2_updated.csv', 'Dataset'] = 'T2'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT3_updated.csv', 'Dataset'] = 'T3'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT4_updated.csv', 'Dataset'] = 'T4'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT5_updated.csv', 'Dataset'] = 'T5'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT6_updated.csv', 'Dataset'] = 'T6'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT7_updated.csv', 'Dataset'] = 'T7'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT8_updated.csv', 'Dataset'] = 'T8'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT9_updated.csv', 'Dataset'] = 'T9'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT10_updated.csv', 'Dataset'] = 'T10'
scores_data_85.loc[scores_data_85['Dataset'] == 'setapProcessT11_updated.csv', 'Dataset'] = 'T11'
scores_data_85.loc[scores_data_85['Dataset'] == 'darwin_data_updated.csv', 'Dataset'] = 'darwin'
scores_data_85.loc[scores_data_85['Dataset'] == 'period_data_updated.csv', 'Dataset'] = 'period'
scores_data_85.loc[scores_data_85['Dataset'] == 'voice_data_updated.csv', 'Dataset'] = 'voice'
scores_data_85.loc[scores_data_85['Dataset'] == 'toxicity_data_updated.csv', 'Dataset'] = 'toxicity'
scores_data_85.loc[scores_data_85['Dataset'] == 'colon 2000.csv', 'Dataset'] = 'colon 2000'
scores_data_85.loc[scores_data_85['Dataset'] == 'leukemia.csv', 'Dataset'] = 'leukemia'
scores_data_85.loc[scores_data_85['Dataset'] == 'gastroenterology.csv', 'Dataset'] = 'gastroenterology'
scores_data_85.loc[scores_data_85['Dataset'] == 'gastric cancer.csv', 'Dataset'] = 'gastric cancer'
scores_data_85.loc[scores_data_85['Dataset'] == 'DLBCL.csv', 'Dataset'] = 'DLBCL'

# Displaying the updated DataFrame to confirm the change
scores_data_85
# Out:
#        Algorithm   Dataset                      Model  Fold Number  Accuracy  \
# 0       Original        T1  Support Vector Classifier            1  0.692308
# 1       Original        T1  Support Vector Classifier            2  0.615385
# 2       Original        T1  Support Vector Classifier            3  0.615385
# 3       Original        T1  Support Vector Classifier            4  0.692308
# 4       Original        T1  Support Vector Classifier            5  0.500000
# ...          ...       ...                        ...          ...       ...
# 3595  ReliefFTwo  leukemia        K Nearest Neighbour            1  1.000000
# 3596  ReliefFTwo  leukemia        K Nearest Neighbour            2  0.933333
# 3597  ReliefFTwo  leukemia        K Nearest Neighbour            3  0.928571
# 3598  ReliefFTwo  leukemia        K Nearest Neighbour            4  0.714286
# 3599  ReliefFTwo  leukemia        K Nearest Neighbour            5  0.928571
#
# ...

# %%
meanF1_main = scores_data["F1"].mean()
meanF1_55 = scores_data_55["F1"].mean()
meanF1_60 = scores_data_60["F1"].mean()
meanF1_65 = scores_data_65["F1"].mean()
meanF1_75 = scores_data_75["F1"].mean()
meanF1_80 = scores_data_80["F1"].mean()
meanF1_85 = scores_data_85["F1"].mean()

# %%
import matplotlib.pyplot as plt

# Mean F1 scores for various datasets
datasets = [
    "70",
    "55 (Main)",
    "60",
    "65",
    "75",
    "80",
    "85"
]
mean_f1_scores_datasets = [
    meanF1_main,
    meanF1_55,
    meanF1_60,
    meanF1_65,
    meanF1_75,
    meanF1_80,
    meanF1_85
]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(datasets, mean_f1_scores_datasets, color='seagreen')
plt.xlabel('Dataset',fontsize='large')
plt.ylabel('Mean F1 Score',fontsize='large')
plt.title('Mean F1 Scores',fontsize='large')
plt.tight_layout()

plt.show()

# %%
# Updating the variable assignments to reflect mean accuracy scores for each dataset
meanAccuracy_main = scores_data["Accuracy"].mean()
meanAccuracy_55 = scores_data_55["Accuracy"].mean()
meanAccuracy_60 = scores_data_60["Accuracy"].mean()
meanAccuracy_65 = scores_data_65["Accuracy"].mean()
meanAccuracy_75 = scores_data_75["Accuracy"].mean()
meanAccuracy_80 = scores_data_80["Accuracy"].mean()
meanAccuracy_85 = scores_data_85["Accuracy"].mean()

# Mean Accuracy scores for various datasets
mean_accuracy_scores_datasets = [
    meanAccuracy_main,
    meanAccuracy_55,
    meanAccuracy_60,
    meanAccuracy_65,
    meanAccuracy_75,
    meanAccuracy_80,
    meanAccuracy_85
]

# Plotting the mean Accuracy scores
plt.figure(figsize=(10, 6))
plt.bar(datasets, mean_accuracy_scores_datasets, color='royalblue')
plt.xlabel('Dataset',fontsize='large')
plt.ylabel('Mean Accuracy',fontsize='large')
plt.title('Mean Accuracy',fontsize='large')
plt.tight_layout()

plt.show()

# %%
# Correcting the query based on the context, assuming the intent is to find the mean F1 score for "Original" algorithm and "Support Vector Classifier" model
mean_f1_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
mean_f1_55_svc = scores_data_55[(scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
mean_f1_60_svc = scores_data_60[(scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
mean_f1_65_svc = scores_data_65[(scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
mean_f1_75_svc = scores_data_75[(scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
mean_f1_80_svc = scores_data_80[(scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
mean_f1_85_svc = scores_data_85[(scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features (Main)','60% features','65% features','70% features','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison', color=colors, width = 0.7,fontsize='large')

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2,fontsize='large')

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.7472285740312316, 0.7353678911889292, 0.7260188799141708, 0.711568277716864, 0.7119703552826757, 0.7083405517505914, 0.7056472727760564], 'Decision Tree': [0.6851908436040145, 0.6899008861078357, 0.6827697685087701, 0.6822562794162988, 0.679333102779397, 0.6884106050418306, 0.6806288080168185], 'Random Forest': [0.748348416992982, 0.7454455958320623, 0.7457471204351027, 0.7440808785881564, 0.7423676701063894, 0.7417965587746003, 0.7418423859729057], 'Gaussian Naive Bayes': [0.663836156006994, 0.6528136237452744, 0.6536182852258503, 0.6441603142441578, 0.6511432734557494, 0.6492216638149865, 0.6457249115197046], 'Gradient Boosting': [0.7186181652855749, 0.7155688607605785, 0.7166673661520756, 0.7154407909499797, 0.7130164046626258, 0.7189642779063458, 0.7123746459746428], 'K Nearest Neighbour': [0.7510940631980287, 0.7440005589851466, 0.7442202311222268, 0.7375363636358744, 0.7430742381872699, 0.7428855465961915, 0.7383938510535412]}

# %%
mean_accuracy_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_55_svc = scores_data_55[(scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_60_svc = scores_data_60[(scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features (main)', '60% features', '65% features', '70% features', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison', color=colors, width=0.7,fontsize='large')

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2,fontsize='large')

# Show the plot
plt.show()

# %%
mean_precision_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")]["Precision"].mean()

mean_precision_55_svc = scores_data_55[(scores_data_55["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_55_dt = scores_data_55[(scores_data_55["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_55_rf = scores_data_55[(scores_data_55["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_55_nb = scores_data_55[(scores_data_55["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_55_gb = scores_data_55[(scores_data_55["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_55_knn = scores_data_55[(scores_data_55["Model"] == "K Nearest Neighbour")]["Precision"].mean()

mean_precision_60_svc = scores_data_60[(scores_data_60["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_60_dt = scores_data_60[(scores_data_60["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_60_rf = scores_data_60[(scores_data_60["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_60_nb = scores_data_60[(scores_data_60["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_60_gb = scores_data_60[(scores_data_60["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_60_knn = scores_data_60[(scores_data_60["Model"] == "K Nearest Neighbour")]["Precision"].mean()

mean_precision_65_svc = scores_data_65[(scores_data_65["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_65_dt = scores_data_65[(scores_data_65["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_65_rf = scores_data_65[(scores_data_65["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_65_nb = scores_data_65[(scores_data_65["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_65_gb = scores_data_65[(scores_data_65["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_65_knn = scores_data_65[(scores_data_65["Model"] == "K Nearest Neighbour")]["Precision"].mean()

mean_precision_75_svc = scores_data_75[(scores_data_75["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_75_dt = scores_data_75[(scores_data_75["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_75_rf = scores_data_75[(scores_data_75["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_75_nb = scores_data_75[(scores_data_75["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_75_gb = scores_data_75[(scores_data_75["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_75_knn = scores_data_75[(scores_data_75["Model"] == "K Nearest Neighbour")]["Precision"].mean()

mean_precision_80_svc = scores_data_80[(scores_data_80["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_80_dt = scores_data_80[(scores_data_80["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_80_rf = scores_data_80[(scores_data_80["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_80_nb = scores_data_80[(scores_data_80["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_80_gb = scores_data_80[(scores_data_80["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_80_knn = scores_data_80[(scores_data_80["Model"] == "K Nearest Neighbour")]["Precision"].mean()

mean_precision_85_svc = scores_data_85[(scores_data_85["Model"] == "Support Vector Classifier")]["Precision"].mean()
mean_precision_85_dt = scores_data_85[(scores_data_85["Model"] == "Decision Tree Classifier")]["Precision"].mean()
mean_precision_85_rf = scores_data_85[(scores_data_85["Model"] == "Random Forest Classifier")]["Precision"].mean()
mean_precision_85_nb = scores_data_85[(scores_data_85["Model"] == "Gaussian Naive Bayes")]["Precision"].mean()
mean_precision_85_gb = scores_data_85[(scores_data_85["Model"] == "Gradient Boosting Classifier")]["Precision"].mean()
mean_precision_85_knn = scores_data_85[(scores_data_85["Model"] == "K Nearest Neighbour")]["Precision"].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Precision score comparison
Precision_score_comparison = {
    'Support Vector Classifier': [mean_precision_55_svc, mean_precision_60_svc, mean_precision_65_svc, mean_precision_main_svc, mean_precision_75_svc, mean_precision_80_svc, mean_precision_85_svc],
    'Decision Tree': [mean_precision_55_dt, mean_precision_60_dt, mean_precision_65_dt, mean_precision_main_dt, mean_precision_75_dt, mean_precision_80_dt, mean_precision_85_dt],
    'Random Forest': [mean_precision_55_rf, mean_precision_60_rf, mean_precision_65_rf, mean_precision_main_rf, mean_precision_75_rf, mean_precision_80_rf, mean_precision_85_rf],
    'Gaussian Naive Bayes': [mean_precision_55_nb, mean_precision_60_nb, mean_precision_65_nb, mean_precision_main_nb, mean_precision_75_nb, mean_precision_80_nb, mean_precision_85_nb],
    'Gradient Boosting': [mean_precision_55_gb, mean_precision_60_gb, mean_precision_65_gb, mean_precision_main_gb, mean_precision_75_gb, mean_precision_80_gb, mean_precision_85_gb],
    'K Nearest Neighbour': [mean_precision_55_knn, mean_precision_60_knn, mean_precision_65_knn, mean_precision_main_knn, mean_precision_75_knn, mean_precision_80_knn, mean_precision_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Precision comparison plot creation
the_plot = pd.DataFrame.from_dict(Precision_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Precision Comparison', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %%
mean_recall_main_svc = scores_data[(scores_data["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_main_dt = scores_data[(scores_data["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_main_rf = scores_data[(scores_data["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_main_nb = scores_data[(scores_data["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_main_gb = scores_data[(scores_data["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_main_knn = scores_data[(scores_data["Model"] == "K Nearest Neighbour")]["Recall"].mean()

mean_recall_55_svc = scores_data_55[(scores_data_55["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_55_dt = scores_data_55[(scores_data_55["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_55_rf = scores_data_55[(scores_data_55["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_55_nb = scores_data_55[(scores_data_55["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_55_gb = scores_data_55[(scores_data_55["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_55_knn = scores_data_55[(scores_data_55["Model"] == "K Nearest Neighbour")]["Recall"].mean()

mean_recall_60_svc = scores_data_60[(scores_data_60["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_60_dt = scores_data_60[(scores_data_60["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_60_rf = scores_data_60[(scores_data_60["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_60_nb = scores_data_60[(scores_data_60["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_60_gb = scores_data_60[(scores_data_60["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_60_knn = scores_data_60[(scores_data_60["Model"] == "K Nearest Neighbour")]["Recall"].mean()

mean_recall_65_svc = scores_data_65[(scores_data_65["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_65_dt = scores_data_65[(scores_data_65["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_65_rf = scores_data_65[(scores_data_65["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_65_nb = scores_data_65[(scores_data_65["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_65_gb = scores_data_65[(scores_data_65["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_65_knn = scores_data_65[(scores_data_65["Model"] == "K Nearest Neighbour")]["Recall"].mean()

mean_recall_75_svc = scores_data_75[(scores_data_75["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_75_dt = scores_data_75[(scores_data_75["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_75_rf = scores_data_75[(scores_data_75["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_75_nb = scores_data_75[(scores_data_75["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_75_gb = scores_data_75[(scores_data_75["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_75_knn = scores_data_75[(scores_data_75["Model"] == "K Nearest Neighbour")]["Recall"].mean()

mean_recall_80_svc = scores_data_80[(scores_data_80["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_80_dt = scores_data_80[(scores_data_80["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_80_rf = scores_data_80[(scores_data_80["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_80_nb = scores_data_80[(scores_data_80["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_80_gb = scores_data_80[(scores_data_80["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_80_knn = scores_data_80[(scores_data_80["Model"] == "K Nearest Neighbour")]["Recall"].mean()

mean_recall_85_svc = scores_data_85[(scores_data_85["Model"] == "Support Vector Classifier")]["Recall"].mean()
mean_recall_85_dt = scores_data_85[(scores_data_85["Model"] == "Decision Tree Classifier")]["Recall"].mean()
mean_recall_85_rf = scores_data_85[(scores_data_85["Model"] == "Random Forest Classifier")]["Recall"].mean()
mean_recall_85_nb = scores_data_85[(scores_data_85["Model"] == "Gaussian Naive Bayes")]["Recall"].mean()
mean_recall_85_gb = scores_data_85[(scores_data_85["Model"] == "Gradient Boosting Classifier")]["Recall"].mean()
mean_recall_85_knn = scores_data_85[(scores_data_85["Model"] == "K Nearest Neighbour")]["Recall"].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Recall score comparison
Recall_score_comparison = {
    'Support Vector Classifier': [mean_recall_55_svc, mean_recall_60_svc, mean_recall_65_svc, mean_recall_main_svc, mean_recall_75_svc, mean_recall_80_svc, mean_recall_85_svc],
    'Decision Tree': [mean_recall_55_dt, mean_recall_60_dt, mean_recall_65_dt, mean_recall_main_dt, mean_recall_75_dt, mean_recall_80_dt, mean_recall_85_dt],
    'Random Forest': [mean_recall_55_rf, mean_recall_60_rf, mean_recall_65_rf, mean_recall_main_rf, mean_recall_75_rf, mean_recall_80_rf, mean_recall_85_rf],
    'Gaussian Naive Bayes': [mean_recall_55_nb, mean_recall_60_nb, mean_recall_65_nb, mean_recall_main_nb, mean_recall_75_nb, mean_recall_80_nb, mean_recall_85_nb],
    'Gradient Boosting': [mean_recall_55_gb, mean_recall_60_gb, mean_recall_65_gb, mean_recall_main_gb, mean_recall_75_gb, mean_recall_80_gb, mean_recall_85_gb],
    'K Nearest Neighbour': [mean_recall_55_knn, mean_recall_60_knn, mean_recall_65_knn, mean_recall_main_knn, mean_recall_75_knn, mean_recall_80_knn, mean_recall_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Recall comparison plot creation
the_plot = pd.DataFrame.from_dict(Recall_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Recall Comparison', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### Original

# %%
mean_f1_main_svc = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_55_svc = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_60_svc = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_65_svc = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_75_svc = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_80_svc = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_85_svc = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features','60% features','65% features','70% features (main)','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison (Original)', color=colors, width = 0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.6974952639971116, 0.6974952639971116, 0.6974952639971116, 0.6974952639971116, 0.6974952639971116, 0.6974952639971116, 0.6974952639971116], 'Decision Tree': [0.6882245126370415, 0.6882245126370415, 0.6882245126370415, 0.6882245126370415, 0.6882245126370415, 0.6882245126370415, 0.6882245126370415], 'Random Forest': [0.7341085612341617, 0.7341085612341617, 0.7341085612341617, 0.7341085612341617, 0.7341085612341617, 0.7341085612341617, 0.7341085612341617], 'Gaussian Naive Bayes': [0.6446960563088993, 0.6446960563088993, 0.6446960563088993, 0.6446960563088993, 0.6446960563088993, 0.6446960563088993, 0.6446960563088993], 'Gradient Boosting': [0.7143091417062739, 0.7143091417062739, 0.7143091417062739, 0.7143091417062739, 0.7143091417062739, 0.7143091417062739, 0.7143091417062739], 'K Nearest Neighbour': [0.730954666931205, 0.730954666931205, 0.730954666931205, 0.730954666931205, 0.730954666931205, 0.730954666931205, 0.730954666931205]}

# %%
mean_accuracy_main_svc = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Algorithm"] == "Original") & (scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_main_svc, mean_accuracy_main_dt)
mean_accuracy_55_svc = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Algorithm"] == "Original") & (scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_55_svc)
mean_accuracy_60_svc = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Algorithm"] == "Original") & (scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Algorithm"] == "Original") & (scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Algorithm"] == "Original") & (scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Algorithm"] == "Original") & (scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Algorithm"] == "Original") & (scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
# Out:
# 0.7080832217750624 0.6588030966398141
# 0.7080832217750624

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (Original)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### SVMRFE

# %%
mean_f1_main_svc = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_55_svc = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_60_svc = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_65_svc = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_75_svc = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_80_svc = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_85_svc = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features','60% features','65% features','70% features (main)','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison (SVMRFE)', color=colors, width = 0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.7702148381256236, 0.7620495664945761, 0.741030566658693, 0.7275622249429762, 0.7147555027737826, 0.705735470138297, 0.7039469758280635], 'Decision Tree': [0.6878506992301417, 0.6952331996962162, 0.676639321918544, 0.6840929869029011, 0.6793274976011616, 0.6848314916376055, 0.6658418281096756], 'Random Forest': [0.7490350624695202, 0.7440628677963158, 0.7513242314318157, 0.7429382988709179, 0.7409993126867217, 0.7409646349152972, 0.7406370845852085], 'Gaussian Naive Bayes': [0.6740691097578768, 0.6632486356774027, 0.6605705985029278, 0.6539261651707875, 0.6534584033410511, 0.6533953998018811, 0.6463604222603999], 'Gradient Boosting': [0.7269705976339174, 0.7261767988093188, 0.7208294491553411, 0.7222247922891684, 0.7165535916344862, 0.7178332076123537, 0.711635746536644], 'K Nearest Neighbour': [0.748850510656979, 0.7456924875380022, 0.7426558749373097, 0.7366434895876816, 0.737884460492637, 0.7411904578746327, 0.7364680143609438]}

# %%
mean_accuracy_main_svc = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Algorithm"] == "SVMRFE") & (scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_main_svc, mean_accuracy_main_dt)

mean_accuracy_55_svc = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Algorithm"] == "SVMRFE") & (scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_55_svc)

mean_accuracy_60_svc = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Algorithm"] == "SVMRFE") & (scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Algorithm"] == "SVMRFE") & (scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Algorithm"] == "SVMRFE") & (scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Algorithm"] == "SVMRFE") & (scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Algorithm"] == "SVMRFE") & (scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
# Out:
# 0.7314266283684691 0.6536134230780816
# 0.7561659194695249

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (SVMRFE)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### ChiSquare

# %%
algorithm = "ChiSquare"  # Replace YourAlgorithmName with the actual name of the algorithm you're using

mean_f1_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features','60% features','65% features','70% features (main)','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison (ChiSquare)', color=colors, width = 0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.7492346443552159, 0.7309590764448655, 0.7225596537216441, 0.7187404037347066, 0.71310783755045, 0.710384626035501, 0.7065315684792466], 'Decision Tree': [0.6838764307824927, 0.6698749798295691, 0.6804900231320817, 0.6650597018074877, 0.6646558836248664, 0.6867129787954666, 0.6727642311784524], 'Random Forest': [0.7524778316363103, 0.7527130307316666, 0.7377268028283176, 0.7440465447154367, 0.7479413077461615, 0.7436880970667081, 0.7430710812467454], 'Gaussian Naive Bayes': [0.6622604024711294, 0.6548475710751172, 0.6538689648297823, 0.6525360246571599, 0.6510996143504887, 0.6421390152405055, 0.6394306621968704], 'Gradient Boosting': [0.7161063995779009, 0.7079269440166774, 0.7163837460124728, 0.7159180855333074, 0.7108940381109676, 0.7226734584750422, 0.7146064008987978], 'K Nearest Neighbour': [0.7537952038274104, 0.7413989791753878, 0.7428519906044293, 0.7402387644339925, 0.7366254681576215, 0.742480236597467, 0.7375965548045776]}

# %%
algorithm = "ChiSquare"

mean_accuracy_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_main_svc, mean_accuracy_main_dt)

mean_accuracy_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_55_svc)

mean_accuracy_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
# Out:
# 0.7300216833135241 0.6429475555648232
# 0.7447829524365578

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (ChiSquare)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### ReliefF

# %%
algorithm = "ReliefF"  # Replace YourAlgorithmName with the actual name of the algorithm you're using

mean_f1_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features','60% features','65% features','70% features (main)','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison (ReliefF)', color=colors, width = 0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.7414483891978209, 0.7229350862279051, 0.7194803296237171, 0.7098493805725351, 0.7068309969153255, 0.7088848473626002, 0.7061553301067], 'Decision Tree': [0.6649326470049133, 0.7142570772159291, 0.676953638659092, 0.6958868794248834, 0.6761446144091124, 0.6913382356741554, 0.6874803059823222], 'Random Forest': [0.7489499802183588, 0.7450883054284322, 0.7531552837413434, 0.746623261428041, 0.741526196874001, 0.7385919102987453, 0.746135817039807], 'Gaussian Naive Bayes': [0.659817616321216, 0.6328986995041918, 0.6632117792963732, 0.6283318645984476, 0.6493327030804633, 0.661848979616269, 0.6487149585328426], 'Gradient Boosting': [0.7161499131984777, 0.7159369772503799, 0.7180090053448225, 0.7230887362353927, 0.7150451052887357, 0.7140699474220316, 0.7154726435607094], 'K Nearest Neighbour': [0.7521301422888226, 0.7323675157435073, 0.7431853527784688, 0.7422098265896782, 0.7469916451349955, 0.7504430916962518, 0.7376216243340206]}

# %%
algorithm = "ReliefF"

mean_accuracy_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_main_svc, mean_accuracy_main_dt)

mean_accuracy_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_55_svc)

mean_accuracy_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
# Out:
# 0.7250532720284143 0.6671301710675999
# 0.7405654063362317

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (ReliefF)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### RiceVD

# %%
algorithm = "Variable ReliefF"  # Replace YourAlgorithmName with the actual name of the algorithm you're using

mean_f1_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features','60% features','65% features','70% features (main)','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison (RiceVD-Sujit)', color=colors, width = 0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.7494169625642201, 0.7440461061850874, 0.7252745623573764, 0.7170498254699419, 0.7136075156260209, 0.708899004523648, 0.7075991505232825], 'Decision Tree': [0.6851597209008404, 0.6861324726103989, 0.669201234832761, 0.6801647345673903, 0.682592885215107, 0.679811784656796, 0.6892492582569723], 'Random Forest': [0.7516472879835964, 0.7383103518821453, 0.7490535418404124, 0.7539465227185961, 0.7466059435998179, 0.7416545842515413, 0.7419308503868386], 'Gaussian Naive Bayes': [0.6760651704283717, 0.6629594979059751, 0.6547737922897086, 0.6441932296051707, 0.6495846589493446, 0.6555979407081685, 0.6516585223432219], 'Gradient Boosting': [0.7185837892392399, 0.7131643031880838, 0.7105699458205202, 0.70483633672942, 0.710397029230522, 0.7183200746187155, 0.7060652213090957], 'K Nearest Neighbour': [0.7667664639470977, 0.759990944133691, 0.7588857711518209, 0.7565269144168225, 0.7577593660286527, 0.7457283174804682, 0.7430387257921219]}

# %%
algorithm = "Variable ReliefF"

mean_accuracy_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_main_svc, mean_accuracy_main_dt)

mean_accuracy_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_55_svc)

mean_accuracy_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
# Out:
# 0.7328452780615968 0.6547565430721504
# 0.7436155140716337

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features', '60% features', '65% features', '70% features (main)', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (RiceVD-Sujit)', color=colors, width=0.7)

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2)

# Show the plot
plt.show()

# %% [markdown]
# #### RiceVDTwo

# %%
algorithm = "ReliefFTwo"  # Replace YourAlgorithmName with the actual name of the algorithm you're using

mean_f1_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["F1"].mean()

mean_f1_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["F1"].mean()
mean_f1_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["F1"].mean()
mean_f1_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["F1"].mean()
mean_f1_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["F1"].mean()
mean_f1_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["F1"].mean()
mean_f1_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["F1"].mean()

# %%
import matplotlib.pyplot as plt
# F1 score
F1_score_comparison = {
    'Support Vector Classifier': [mean_f1_55_svc, mean_f1_60_svc,mean_f1_65_svc,mean_f1_main_svc,mean_f1_75_svc,mean_f1_80_svc,mean_f1_85_svc],
    'Decision Tree': [mean_f1_55_dt, mean_f1_60_dt,mean_f1_65_dt,mean_f1_main_dt,mean_f1_75_dt,mean_f1_80_dt,mean_f1_85_dt],
    'Random Forest': [mean_f1_55_rf, mean_f1_60_rf,mean_f1_65_rf,mean_f1_main_rf,mean_f1_75_rf,mean_f1_80_rf,mean_f1_85_rf],
    'Gaussian Naive Bayes': [mean_f1_55_nb, mean_f1_60_nb,mean_f1_65_nb,mean_f1_main_nb,mean_f1_75_nb,mean_f1_80_nb,mean_f1_85_nb],
    'Gradient Boosting': [mean_f1_55_gb, mean_f1_60_gb,mean_f1_65_gb,mean_f1_main_gb,mean_f1_75_gb,mean_f1_80_gb,mean_f1_85_gb],
    'K Nearest Neighbour': [mean_f1_55_knn, mean_f1_60_knn,mean_f1_65_knn,mean_f1_main_knn,mean_f1_75_knn,mean_f1_80_knn,mean_f1_85_knn]
}

print(F1_score_comparison)

colors = ['blue', 'green','black','orange','grey','lightgreen','purple']

# plt.figure(figsize=(1000, 10))  # This makes the figure 15 inches wide and 6 inches tall

# Your data and plot creation code
the_plot = pd.DataFrame.from_dict(F1_score_comparison, orient='index', columns=['55% features (main)','60% features','65% features','70% features (main)','75% features','80% features','85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='F1-Score comparison (RiceVD)', color=colors, width = 0.7,fontsize='large')

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2,fontsize='large')

# Show the plot
plt.show()
# Out:
# {'Support Vector Classifier': [0.7755613459473975, 0.7547222477840296, 0.7502729031264828, 0.6987125675839131, 0.726025014833364, 0.7186440984463904, 0.7121553477219349], 'Decision Tree': [0.7011010510686575, 0.68568307465786, 0.7051098798731005, 0.6801088611580893, 0.6850532231890929, 0.6995446268499189, 0.6802127119364466], 'Random Forest': [0.7538717784159449, 0.7583904579196526, 0.7491143015345654, 0.7428220825617852, 0.743024698497473, 0.7517715648811485, 0.7451709213446732], 'Gaussian Naive Bayes': [0.6661085807544705, 0.6582312820000604, 0.6445885201274107, 0.6412785451244813, 0.6586882047042499, 0.6376525912141957, 0.6434888474759939], 'Gradient Boosting': [0.7195891503576404, 0.7158989995927375, 0.7199029088730237, 0.7122676532063165, 0.7108995220047689, 0.7265798376036586, 0.7121587218363366], 'K Nearest Neighbour': [0.7540673915366577, 0.7535987603890867, 0.7467877303301269, 0.718644519855866, 0.7482298223785075, 0.7465165089971247, 0.7446835200983779]}

# %%
algorithm = "ReliefFTwo"

mean_accuracy_main_svc = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_main_dt = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_main_rf = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_main_nb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_main_gb = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_main_knn = scores_data[(scores_data["Algorithm"] == algorithm) & (scores_data["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_main_svc, mean_accuracy_main_dt)

mean_accuracy_55_svc = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_55_dt = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_55_rf = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_55_nb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_55_gb = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_55_knn = scores_data_55[(scores_data_55["Algorithm"] == algorithm) & (scores_data_55["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
print(mean_accuracy_55_svc)

mean_accuracy_60_svc = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_60_dt = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_60_rf = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_60_nb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_60_gb = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_60_knn = scores_data_60[(scores_data_60["Algorithm"] == algorithm) & (scores_data_60["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_65_svc = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_65_dt = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_65_rf = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_65_nb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_65_gb = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_65_knn = scores_data_65[(scores_data_65["Algorithm"] == algorithm) & (scores_data_65["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_75_svc = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_75_dt = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_75_rf = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_75_nb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_75_gb = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_75_knn = scores_data_75[(scores_data_75["Algorithm"] == algorithm) & (scores_data_75["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_80_svc = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_80_dt = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_80_rf = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_80_nb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_80_gb = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_80_knn = scores_data_80[(scores_data_80["Algorithm"] == algorithm) & (scores_data_80["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()

mean_accuracy_85_svc = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Support Vector Classifier")]["Accuracy"].mean()
mean_accuracy_85_dt = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Decision Tree Classifier")]["Accuracy"].mean()
mean_accuracy_85_rf = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Random Forest Classifier")]["Accuracy"].mean()
mean_accuracy_85_nb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gaussian Naive Bayes")]["Accuracy"].mean()
mean_accuracy_85_gb = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "Gradient Boosting Classifier")]["Accuracy"].mean()
mean_accuracy_85_knn = scores_data_85[(scores_data_85["Algorithm"] == algorithm) & (scores_data_85["Model"] == "K Nearest Neighbour")]["Accuracy"].mean()
# Out:
# 0.7158397425471429 0.6568661025038636
# 0.757132287083568

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming pd is not already imported

# Accuracy score comparison
Accuracy_score_comparison = {
    'Support Vector Classifier': [mean_accuracy_55_svc, mean_accuracy_60_svc, mean_accuracy_65_svc, mean_accuracy_main_svc, mean_accuracy_75_svc, mean_accuracy_80_svc, mean_accuracy_85_svc],
    'Decision Tree': [mean_accuracy_55_dt, mean_accuracy_60_dt, mean_accuracy_65_dt, mean_accuracy_main_dt, mean_accuracy_75_dt, mean_accuracy_80_dt, mean_accuracy_85_dt],
    'Random Forest': [mean_accuracy_55_rf, mean_accuracy_60_rf, mean_accuracy_65_rf, mean_accuracy_main_rf, mean_accuracy_75_rf, mean_accuracy_80_rf, mean_accuracy_85_rf],
    'Gaussian Naive Bayes': [mean_accuracy_55_nb, mean_accuracy_60_nb, mean_accuracy_65_nb, mean_accuracy_main_nb, mean_accuracy_75_nb, mean_accuracy_80_nb, mean_accuracy_85_nb],
    'Gradient Boosting': [mean_accuracy_55_gb, mean_accuracy_60_gb, mean_accuracy_65_gb, mean_accuracy_main_gb, mean_accuracy_75_gb, mean_accuracy_80_gb, mean_accuracy_85_gb],
    'K Nearest Neighbour': [mean_accuracy_55_knn, mean_accuracy_60_knn, mean_accuracy_65_knn, mean_accuracy_main_knn, mean_accuracy_75_knn, mean_accuracy_80_knn, mean_accuracy_85_knn]
}

colors = ['blue', 'green', 'black', 'orange', 'grey', 'lightgreen', 'purple']

# Accuracy comparison plot creation
the_plot = pd.DataFrame.from_dict(Accuracy_score_comparison, orient='index', columns=['55% features (main)', '60% features', '65% features', '70% features', '75% features', '80% features', '85% features'])
ax = the_plot.plot(kind='bar', rot=30, title='Accuracy Comparison (RiceVD)', color=colors, width=0.7,fontsize='large')

# Adjust the figure size
fig = plt.gcf()  # Get the current figure
fig.set_size_inches(15, 6)  # Set the figure size

# Adjust the legend position
plt.legend(loc='upper center', bbox_to_anchor=(1, 1.35), shadow=True, ncol=2,fontsize='large')

# Show the plot
plt.show()
